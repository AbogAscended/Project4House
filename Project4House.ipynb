# %%
import pandas as pd
import xgboost as xgb
import sklearn as sk
from sklearn.pipeline import Pipeline

# %%
# Read both test and training data into variables using pandas
train_data = pd.read_csv('data/train.csv')
test_data = pd.read_csv('data/test.csv')

# %%
# Lets look at the data and see what we are working with, what categorical data and numerical data we have.
# We also need to look at what our Y is and remove that so that we can use it for training the actual model.
# Here SalePrice is our y so we will need to create a y_train variable
train_data

# %%
# This creates a dataframe which does not have the column SalePrice or Id
train_no_y = train_data[[col for col in train_data.columns if col != 'SalePrice' and col != 'Id']]
train_no_y
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... ScreenPorch PoolArea PoolQC  Fence  \
# ...

# %%
# This takes the column with the title SalePRice and makes a new data frame containing only 
# this column so we can use it to actually train the model.
y_train = train_data['SalePrice']

# %%
'''
Now for the hard part, we need to try to turn the categorical variables in the numerical values that make sense
Im going to try to use ordinal encoding on variables I think are related to each other and one hot encoding for
everything else. Some things im just going to straight up remove that are far too specific.
MSZoning has two good seperate categories to use two different types of encoding:
       FV	Floating Village Residential
       RH	Residential High Density
       RL	Residential Low Density
       RP	Residential Low Density Park 
       RM	Residential Medium Density
These are great candidates for ordinal encoding as they have a relationship with each other.

While for these:
       A	Agriculture
       C	Commercial
       I	Industrial
Ill just use regular old one hot encoding


Ill use ordinal encoding as one is definitely worth more than the other and they're related:
grvl vs pave


Alley:
I will use the same ordinal encoding

LotShape:
Ordinal Encoding

Land contour:
One hot

utilities
ordinal encoding

lotconfig:
ordinal encoding

landslope:
ordinal

neighborhood:
one hot

etc...

'''
# Out:
# '\nNow for the hard part, we need to try to turn the categorical variables in the numerical values that make sense\nIm going to try to use ordinal encoding on variables I think are related to each other and one hot encoding for\neverything else. Some things im just going to straight up remove that are far too specific.\nMSZoning has two good seperate categories to use two different types of encoding. \n       FV\tFloating Village Residential\n       RH\tResidential High Density\n       RL\tResidential Low Density\n       RP\tResidential Low Density Park \n       RM\tResidential Medium Density\nThese are great candidates for ordinal encoding as they have a relationship with each other.\n\nWhile for these\n'

# %%
#For fun we can also try just straight up one hot encoding everything reasonable just remove the stupid things.
# lets practice making a pipeline.

numericalTransformer = 





forFun = Pipeline
